# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()
client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，主要是因為一個物理現象，叫做**「瑞利散射」（Rayleigh scattering）**。
#
# 這過程主要與三個要素有關：**太陽光**、**地球的大氣層**，以及**我們人類的眼睛**。以下為您詳細拆解：
#
# ### 1. 太陽光其實是「彩虹色」的
# 雖然太陽光看起來是白色的，但它其實是由紅、橙、黃、綠、藍、靛、紫等所有顏色的光混合而成的。
# * 這些光以「波」的形式傳播。
# * **紅光、橙光**的波長較**長**。
# * **藍光、紫光**的波長較**短**。
#
# ### 2. 大氣層的阻擋（瑞利散射）
# 地球周圍包圍著厚厚的大氣層，裡面充滿了氮氣和氧氣等氣體分子。
# 當太陽光穿過大氣層時，會與這些微小的氣體分子碰撞：
# * **波長較長的光（如紅光、黃光）**：像大浪一樣，能輕易繞過微小的氣體分子，直接穿透大氣層直達地面。
# * **波長較短的光（如藍光、紫光）**：像小浪碰到礁石一樣，很容易被氣體分子**撞得向四面八方散射開來**。
#
# 因為藍光在空氣中被不斷地散射、反射，充滿了整個天空，所以當我們抬頭看天空時，眼睛接收到的主要就是這些被散射的藍光。
#
# ---
#
# ### 💡 常見的疑問：為什麼天空不是「紫色」的？
# 紫光的波長比藍光還要短，照理說散射得更厲害，那為什麼天空不是紫色的呢？原因有兩個：
#
# 1. **太陽光的組成**：太陽光中藍光的強度本來就比紫光強很多。
# 2. **人類眼睛的構造**：人類的眼睛對「藍色」比對「紫色」敏感得多。我們的視網膜接收到藍光和微量的紫光後，大腦會自動把它處理成我們所看到的蔚藍色。
#
# ---
#
# ### 延伸思考：為什麼夕陽是紅色的？
# 到了傍晚，太陽角度變低，陽光必須穿過**比中午厚很多**的大氣層才能到達我們的眼睛。
# 在這段漫長的路程中，藍光在半路上就已經被散射光了，只剩下穿透力最強、波長最長的**紅光和橙光**能成功抵達我們的眼睛，所以夕陽看起來就是美麗的橘紅色。
